# %% [markdown]
# # 03_Hindcast_AO_NAM_B2000WCN_projection
# Runs script: Hindcast_experiment/date_treatment/scripts/compute_hindcast_ao_nam_b2000wcn_projection.py. Edit arguments in the code cell if needed.

# %%
from pathlib import Path
import runpy
import sys
candidates = [Path("scripts/compute_hindcast_ao_nam_b2000wcn_projection.py"), Path("Hindcast_experiment/date_treatment/scripts/compute_hindcast_ao_nam_b2000wcn_projection.py"), Path("code_cleaned/Hindcast_experiment/date_treatment/scripts/compute_hindcast_ao_nam_b2000wcn_projection.py")]
script = next((p for p in candidates if p.exists()), None)
if script is None:
    raise FileNotFoundError(candidates)
sys.argv = [str(script)]
runpy.run_path(str(script), run_name="__main__")
