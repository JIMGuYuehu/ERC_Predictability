# %% [markdown]
# # 05_Hindcast_FWD
# Runs script: Hindcast_experiment/date_treatment/scripts/compute_hindcast_fwd.py. Edit arguments in the code cell if needed.

# %%
from pathlib import Path
import runpy
import sys
candidates = [Path("scripts/compute_hindcast_fwd.py"), Path("Hindcast_experiment/date_treatment/scripts/compute_hindcast_fwd.py"), Path("code_cleaned/Hindcast_experiment/date_treatment/scripts/compute_hindcast_fwd.py")]
script = next((p for p in candidates if p.exists()), None)
if script is None:
    raise FileNotFoundError(candidates)
sys.argv = [str(script)]
runpy.run_path(str(script), run_name="__main__")
