# %% [markdown]
# # 06_Compare_legacy_EPFlux
# Runs script: Hindcast_experiment/date_treatment/scripts/compare_hindcast_epflux_legacy.py. Edit arguments in the code cell if needed.

# %%
from pathlib import Path
import runpy
import sys
candidates = [Path("scripts/compare_hindcast_epflux_legacy.py"), Path("Hindcast_experiment/date_treatment/scripts/compare_hindcast_epflux_legacy.py"), Path("code_cleaned/Hindcast_experiment/date_treatment/scripts/compare_hindcast_epflux_legacy.py")]
script = next((p for p in candidates if p.exists()), None)
if script is None:
    raise FileNotFoundError(candidates)
sys.argv = [str(script)]
runpy.run_path(str(script), run_name="__main__")
