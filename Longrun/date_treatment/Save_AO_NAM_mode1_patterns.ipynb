# %% [markdown]
# # Save AO/NAM Mode-1 Patterns
# Preserves first EOF modes for the requested Longrun cases.

# %%
from pathlib import Path
import runpy
import sys
candidates = [Path("save_longrun_ao_nam_mode1_patterns.py"), Path("Longrun/date_treatment/save_longrun_ao_nam_mode1_patterns.py"), Path("code_cleaned/Longrun/date_treatment/save_longrun_ao_nam_mode1_patterns.py")]
script = next((p for p in candidates if p.exists()), None)
if script is None:
    raise FileNotFoundError(candidates)
sys.argv = [str(script)]
runpy.run_path(str(script), run_name="__main__")
